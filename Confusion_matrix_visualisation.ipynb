# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

# Assuming you have the true labels and predictions (y_true and y_pred)
y_true = np.array([0] * 391 + [1] * 69)  # Replace with your actual true labels
y_pred = np.array([0] * 391 + [0] * 68 + [1] * 1)  # Replace with your actual predicted labels

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Plotting Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='g', cmap='Greens', xticklabels=[' Positive', 'Negative'], yticklabels=['Positive', 'Negative'])
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

# Classification Report
report = classification_report(y_true, y_pred, output_dict=True)

# Extracting precision, recall, and f1-score for classes 0 and 1
classes = ['0', '1']
metrics = ['precision', 'recall', 'f1-score']

# Plotting Classification Report
fig, ax = plt.subplots(figsize=(8, 6))

for i, metric in enumerate(metrics):
    ax.bar(classes, [report[class_][metric] for class_ in classes], label=metric)

ax.set_title('Classification Report Metrics')
ax.set_ylabel('Score')
ax.set_xlabel('Class')
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

# Assuming you have the true labels and predictions (y_true and y_pred)
y_true = np.array([0] * 436 + [1] * 69)  # Replace with your actual true labels
y_pred = np.array([0] * 436 + [0] * 67 + [1] * 2)  # Replace with your actual predicted labels

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Plotting Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='g', cmap='Greens', xticklabels=[' Positive', 'Negative'], yticklabels=['Positive', 'Negative'])
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

# Classification Report
report = classification_report(y_true, y_pred, output_dict=True)

# Extracting precision, recall, and f1-score for classes 0 and 1
classes = ['0', '1']
metrics = ['precision', 'recall', 'f1-score']

# Plotting Classification Report
fig, ax = plt.subplots(figsize=(8, 6))

for i, metric in enumerate(metrics):
    ax.bar(classes, [report[class_][metric] for class_ in classes], label=metric)

ax.set_title('Classification Report Metrics')
ax.set_ylabel('Score')
ax.set_xlabel('Class')
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

# Assuming you have the true labels and predictions (y_true and y_pred)
y_true = np.array([0] * 391 + [1] * 69)  # Replace with your actual true labels
y_pred = np.array([0] * 385 + [1] * 6 + [0] * 59 + [1] * 10)  # Replace with your actual predicted labels

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Plotting Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='g', cmap='Greens', xticklabels=[' Positive', 'Negative'], yticklabels=['Positive', 'Negative'])
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

# Classification Report
report = classification_report(y_true, y_pred, output_dict=True)

# Extracting precision, recall, and f1-score for classes 0 and 1
classes = ['0', '1']
metrics = ['precision', 'recall', 'f1-score']

# Plotting Classification Report
fig, ax = plt.subplots(figsize=(8, 6))

for i, metric in enumerate(metrics):
    ax.bar(classes, [report[class_][metric] for class_ in classes], label=metric)

ax.set_title('Classification Report Metrics')
ax.set_ylabel('Score')
ax.set_xlabel('Class')
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

# Assuming you have the true labels and predictions (y_true and y_pred)
y_true = np.array([0] * 436 + [1] * 69)  # Replace with your actual true labels
y_pred = np.array([0] * 396 + [1] * 40 + [0] * 59 + [1] * 10)  # Replace with your actual predicted labels

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Plotting Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='g', cmap='Greens', xticklabels=[' Positive', 'Negative'], yticklabels=['Positive', 'Negative'])
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

# Classification Report
report = classification_report(y_true, y_pred, output_dict=True)

# Extracting precision, recall, and f1-score for classes 0 and 1
classes = ['0', '1']
metrics = ['precision', 'recall', 'f1-score']

# Plotting Classification Report
fig, ax = plt.subplots(figsize=(8, 6))

for i, metric in enumerate(metrics):
    ax.bar(classes, [report[class_][metric] for class_ in classes], label=metric)

ax.set_title('Classification Report Metrics')
ax.set_ylabel('Score')
ax.set_xlabel('Class')
ax.legend()
plt.show()
